# %% [markdown]
# <a href="https://colab.research.google.com/github/AlvinManoj05/Data-Preprocessing-Project/blob/main/Data_Processing_Group_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Load Dataset

# %%
df=pd.read_csv("/content/istanbul_sales_data.csv")

# %% [markdown]
# ## 3.Data Understanding

# %%
df.head()
# Out:
#   invoice_no customer_id  gender   age    category  quantity    price  \
# 0    I100001     C313884  Female  28.0    Clothing       2.0   600.16
# 1    I100002     C311565    Male  22.0  Technology       1.0  2100.00
# 2    I100003     C366599    Male  20.0    Clothing       1.0   300.08
# 3    I100004     C388172  Female  66.0       Books       5.0    75.75
# 4    I100005     C389076  Female  53.0   Cosmetics       4.0   162.64
#
#   payment_method invoice_date shopping_mall
# 0    Credit Card   2023-05-18  Istinye Park
# 1    Credit Card   2024-02-12  Zorlu Center
# 2           Cash   2023-09-11     Metrocity
# 3    Credit Card   2024-01-28  Metropol AVM
# 4           Cash   2023-10-24   Cevahir AVM

# %% [markdown]
# ## 4.Missing Values Check

# %%
df.isna().sum()
# Out:
# invoice_no        0
# customer_id       1
# gender            1
# age               1
# category          1
# quantity          1
# price             1
# payment_method    1
# invoice_date      1
# shopping_mall     1
# dtype: int64

# %%
df.isna()/len(df)*100
# Out:
#      invoice_no  customer_id    gender       age  category  quantity  \
# 0           0.0     0.000000  0.000000  0.000000  0.000000  0.000000
# 1           0.0     0.000000  0.000000  0.000000  0.000000  0.000000
# 2           0.0     0.000000  0.000000  0.000000  0.000000  0.000000
# 3           0.0     0.000000  0.000000  0.000000  0.000000  0.000000
# 4           0.0     0.000000  0.000000  0.000000  0.000000  0.000000
# ..          ...          ...       ...       ...       ...       ...
# 499         0.0     0.000000  0.000000  0.000000  0.000000  0.000000
# 500         0.0     0.000000  0.000000  0.000000  0.000000  0.000000
# 501         0.0     0.000000  0.000000  0.000000  0.000000  0.000000
# 502         0.0     0.000000  0.000000  0.000000  0.000000  0.000000
# 503         0.0     0.198413  0.198413  0.198413  0.198413  0.198413
#
#         price  payment_method  invoice_date  shopping_mall
# 0    0.000000        0.000000      0.000000       0.000000
# 1    0.000000        0.000000      0.000000       0.000000
# 2    0.000000        0.000000      0.000000       0.000000
# 3    0.000000        0.000000      0.000000       0.000000
# 4    0.000000        0.000000      0.000000       0.000000
# ..        ...             ...           ...            ...
# 499  0.000000        0.000000      0.000000       0.000000
# 500  0.000000        0.000000      0.000000       0.000000
# 501  0.000000        0.000000      0.000000       0.000000
# 502  0.000000        0.000000      0.000000       0.000000
# 503  0.198413        0.198413      0.198413       0.198413
#
# [504 rows x 10 columns]
